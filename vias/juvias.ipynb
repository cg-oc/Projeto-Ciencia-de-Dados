# %% [markdown]
# # Ilumândia
# <p>Imagine o arquipélago da Ilumândia, lar da antiga civilização dos ilummers. Você é um arqueólogo encarregado de estudar sobre as conexões das ilhas desse povo ancestral. Sabemos que suas ilhas eram conectadas por rodovias ou por hidrovias, sendo que no máximo uma rodovia foi construída a cada ano, mas todas as hidrovias presentes já haviam sido construídas previamente.</p>
#
# <h2>Objetivo</h2>
# <p>Com base na estrutura das rodovias e hidrovias atualmente, seu trabalho é determinar se o arquipélago era simples ou não há anos atrás.</p>
# <ul>
#     <li>Um arquipélago é simples se não há mais que um caminho a uma mesma ilha.</li>
# </ul>
#
# <h2>Entradas</h2>
# <p>O programa recebe inicialmente em uma linha dois números inteiros, P e Q, em que P representa o número de conexões entre ilhas, e Q, a quantidade de anos atrás que o arquipélago será analisado. Então, o usuário deve fornecer um número P de conexões entre ilhas, uma de cada vez, da seguinte forma:<br></p>
# <code>&lt;Número de conexões a serem fornecidas&gt; &lt;Anos em que o arquipélago será valiado&gt;</code>
#
# <code>&lt;ilha 1&gt; &lt;ilha 2&gt; &lt;tipo de via (h - para hidrovias, h - para rodovias)&gt;</code>
#
# ...
#
# <p> Exmeplo:</p>
# <ul>
#     <li><span style="color: orange;">1 1</span></li>
# </ul>
# <p>Inidica que uma conexão será fornecida e o arquipélago será avaliado em 1 ano no passado</p>
# <ul>
#     <li><span style="color: orange;">Hakuna Mattata r</span></li>
# </ul>
# <p>Indica que as ilhas Hakuna e Mattata são ligadas por uma rodovia.</p>
#
# <h2>Saída</h2>
# <p>TODO</p>
#
# <h2>Algoritmo - Visão geral</h2>
# <p>Esse projeto baseia-se na interpretação do arquipélago e suas ilhas como grafos e vértices, respectivamente. Dessa forma, dois ou mais caminhos para uma ilha são representados por um laço. Logo, o algoritmo primeiro constrói o(s) grafo(s) somente com hidrovias e verifica se há algum laço nele(s). Como nenhuma hidrovoia foi construída após o período estudado, um laço de hidrovia significa diretamente que o arquipélago não era simples. Após isso, as rodovias são adicionadas uma a uma e o arquipélago é analisado novamente em busca de algum laço.
# A CONTINUAR</p>
#
# <h2>Acompanhamento</h2>
# <p>A cada etapa de análise do arquipélago, uma imagem é gerada para representar a visualização do grafo, apresentando o número de anos considerado, quantos laços de rodovia já foram notados, quais rodovias foram adicionas ou removidas.</p>

# %% [markdown]
# <h2>Imports</h2>
#
# <ul>
#     <li>Função exit - Para encerrar o programa em caso de KeyboardInterrupt</li>
#     <li>Função draw e classe Graph - Para gerar o PNG do grafo</li>
#     <li>matplotlib.pyplot - Para formatar e adicionar elementos à imagem gerada</li>
# </ul>

# %%
from sys import exit
from networkx import Graph, draw
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Class Arquipelago</h2>
# <p> A partir do número de conexões e a quantidade de anos do período em estudo, ela cria
# um objeto que representa o arquipélago e armazena todas as informações relevantes sobre ele,
# como quais rodovias há, seu grafo e quantos loops já foram detectados.</p>

# %%
class Arquipelago:
    """
    Representa um arquipélago como grafos para verificar as conexões entre suas ilhas.

    Permite verificar laços e adicionar conexões entre suas ilhas, mantendo salvo os dados do grafo
    correspondente a cada alteração.

    Attributes:
        self.n_conexoes (int): Quantas conexões há entre linhas.
        self.anos (int): Período de estudo do arquipélago.
        self.rodovias (set[tuple]): Guarda os pares de ilhas conectadas por cada rodovia.
        self.grafo (dict[str, set]): Dicionário que representa o grafo.
        self.n_loops (int): Qunatos laços de rodovia já foram detectados.
    """
    def __init__(self, n_conexoes: int, anos: int):
        self.n_conexoes: int = n_conexoes
        self.anos: int = anos
        self.rodovias: set[tuple] = set()
        self.grafo: dict[str, set] = {}
        self.n_loops: int = 0

# %% [markdown]
# <h3>Método <code>mostra_grafo</code></h3>
# <p>Gera .png para mostrar o estado atual do grafo e qual ação/análise foi feita, bem como o período estudado
# e quantos laços de rodovia foram detectados.</p>

# %%
def mostra_grafo(self, mensagem: str = "", cor: str = "blue") -> None:
    """
    Gera .png representando o grafo do arquipélago com todas as hidrovias e as 
    rodovias adicionadas até então.
    Entrada: Uma mensagem em string que será mostrada no fundo do .png e o nome de uma cor em string.
    """
    g = Graph(self.grafo)
    draw(g, with_labels=True, node_color='skyblue')
    plt.figtext(0.5, 0.01, mensagem, wrap=True, horizontalalignment='center', fontsize=12, color=cor)
    plt.title(f"Anos: {self.anos}              Loops de rodovia encontrados: {self.n_loops}")
    plt.savefig("meu_grafo.png", format="PNG", dpi=300, bbox_inches="tight")
    plt.close()
    input("ENTER para continuar")

Arquipelago.mostra_grafo = mostra_grafo

# %% [markdown]
# <h3>Método <code>adiciona_conexao</code></h3>
# <p>Forma a conexão entre dois vértices e registra no grafo</p>

# %%
def adiciona_conexao(self, v1: str, v2: str) -> None:
    """
    Pega dois vértices e adiciona cada um ao conjunto correspondente do outro no grafo.
    Entrada: Dois vértices do grafo, que são strings.
    """
    if self.grafo.get(v1, []):
        self.grafo[v1].add(v2)
    else:
        self.grafo[v1]: set = {v2}

    if self.grafo.get(v2, []):
        self.grafo[v2].add(v1)
    else:
        self.grafo[v2]: set = {v1}

Arquipelago.adiciona_conexao = adiciona_conexao

# %% [markdown]
# <h3>Método <code>remove_conexao</code></h3>
# <p>Apaga a conexão entre dois vértices e remove do grafo</p>

# %%
def remove_conexao(self, v1: str, v2: str) -> None:
    """Pega dois vértices e exclui cada um do do conjunto correspondente do outro no grafo
    Entrada:
        Dois vértices do grafo, que são strings.
    """
    self.grafo[v1].remove(v2)
    self.grafo[v2].remove(v1)

Arquipelago.remove_conexao = remove_conexao

# %% [markdown]
# <h3>Método <code>pega_conexões</code></h3>
# <p>Solicita do usuário as informações sobre as conexões entre as ilhas e as salva na objeto.
# Ao final, gera um PNG com todas as hidrovias.</p>

# %%
def pega_conexoes(self) -> None:
    """
    Pede ao usuário as conexões do arquipélago e as armazena no objeto `Arquipelago`. Rodovias são salvas
    em set exclusivo `self.rodovias`, mas hidrovias são adicionadas ao grafo diretamente.
    """
    while True:
        try:
            for _ in range(self.n_conexoes):
                input_de_via: list = input("vértice 1, vértice 2, tipo de via: ").strip().split(" ") 
                v1, v2, tipo_de_via = input_de_via
                
                if tipo_de_via == "h":
                    self.adiciona_conexao(v1, v2)

                elif tipo_de_via == "r":
                    self.rodovias.add((v1, v2))
                else: 
                    raise ValueError
            break

        except ValueError:
            print("Input inválido!")
        except KeyboardInterrupt:
            exit("\nPrograma finalizado!")

    self.mostra_grafo("Somente hidrovias") # gera PNG
    

Arquipelago.pega_conexoes = pega_conexoes # para acoplar esse método à classe Arquipelago

# %% [markdown]
# <h3>Método <code>pega_ponta</code></h3>
# <p>Retorna algum vértice do grafo que ainda não foi visitado. Se não houver, retorn <code>None</code></p>.

# %%
def pega_ponta(self, visitados: set[str]) -> str | None:
    """
    Busca vértice do grafo que ainda não foi visitado.\n
    Entrada:
        Conjunto de strings representando quais vértices já foram visitados
    Saída:
        Vértice que ainda não foi visitado. Caso não haja, retorna `None`.
    """
    for vertice in self.grafo:
        if vertice not in visitados:
            return vertice
    return None
    
Arquipelago.pega_ponta = pega_ponta

# %% [markdown]
# <h3>Método <code>tem_loop</code><h3>
# <p>Verifica se há loop no grafo do arquipélago construído até o momento.
# Realiza Busca por Profundiade (DFS)</p>

# %%
def tem_loop(self) -> bool:
    """
    Verifica se há loop no grafo atual do arquipélago.\n
    Saída: `True` se houver loop ou `False` caso contrário
    """
    visitados: set[str] = set()

    while ponta:= self.pega_ponta(visitados):
        a_visitar: list[tuple] = [(None, ponta)] # (v_cauda, v_cabeca)
        
        while a_visitar:

            cauda, cabeca = a_visitar.pop() # pega ultimo vertice adicionado
            visitados.add(cabeca)

            for vizinho in self.grafo[cabeca]:
                if vizinho == cauda:
                    continue
                elif vizinho not in visitados:
                    a_visitar.append((cabeca, vizinho)) 
                else:
                    return True
    return False
Arquipelago.tem_loop = tem_loop

# %% [markdown]
# <h3>Método <code>tem_loop_de_rodovias</code><h3>
# <p>Adiciona uma rodovia por vez e busca por algum laço no grafo a cada adição. Há uma contagem de laços de
#     rodovia, e se essa conta superar os anos do período, o arquipélago não era simples.</p>

# %%
def tem_loop_de_rodovias(self) -> bool:
    """
    Adiciona uma rodovia por vez e busca por algum laço no grafo a cada adição. Se encontrar laço, 
    aumenta a contagem de laços em 1.\n
    Saída: Se a contagem for maior que Q anos, retorna `False`, senão, `True`.
    """
    for rodovia in self.rodovias:
        self.adiciona_conexao(*rodovia)
        self.mostra_grafo(f"Adicionada a rodovia entre {rodovia[0]} e {rodovia[1]}")

        if not self.tem_loop():
            continue # rodovia é mantida
        
        self.n_loops += 1 #tem loop
        if self.n_loops > self.anos: #verifica se nao cruzou o limite
            self.mostra_grafo(f"Loops de rodovia demais! Arquipélago não era simples", cor='red')
            return True #arquipelago não era simples
        self.remove_conexao(*rodovia)
        self.mostra_grafo(f"Removida a rodovia entre {rodovia[0]} e {rodovia[1]}")
        
    return False

Arquipelago.tem_loop_de_rodovias = tem_loop_de_rodovias

# %% [markdown]
# <h3>Método <code>era_simples</code></h3>
# <p>Diz se o arquiélago era simples ou não.
# Ele atua como método principal que vai organizar a lógica para chamar outros métodos.
# Primeiro, carrega os dados, verficica se há algum laço apenas com hidrovias, e depois chama
# <code>tem_loop_de_rodovias</code></p>

# %%
def era_simples(self) -> bool:
    """
    Verifica se arquipélago não tem loops de hidrovia e então checa as rodovias uma a uma
    em busca de loops.\n
    Saída: Caso haja loop de hidrovia ou mais loops de rodovia do que anos, retorna
    `False`. Caso contrário, retorna `True`.
    """
    self.pega_conexoes() # carrega dados do arquipelago    

    if self.tem_loop(): # checando primeiro somente com hidrovias
        self.mostra_grafo(f"Há um loop de hidrovia! Arquipélago não era simples", cor='red')            
        return False
    else:
        # agora checa uma rodovia por vez
        return not self.tem_loop_de_rodovias()
        
Arquipelago.era_simples = era_simples

# %% [markdown]
# <h2>Aplicando a classe Arquipelago na prática</h2>
# <p>Segue um exemplo de utilização da classe e seus métodos, solicitando do usuário as entradas para instanciar
# o objeto <code>arquipelago</code> e então buscar se ele era simples ou não.</p>

# %%
while True:
    try:
        n_conexoes, anos = map(int, input("Número de conexões, anos: ").split(" "))
        break
    except ValueError:
        print("Input inválido!")
    except KeyboardInterrupt:
        exit("\nPrograma finalizado!")
arquipelago = Arquipelago(n_conexoes, anos) # instancializa o objeto arquipelago

if arquipelago.era_simples():
    print("O arquipélago era simples!")
else:
    print("O arquipélago não era simples!")
# Out:
# Input inválido!
# Input inválido!
